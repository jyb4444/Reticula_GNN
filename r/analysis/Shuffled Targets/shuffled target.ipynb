# %%
# %load_ext rpy2.ipython

# %%
# %%R
# library(magrittr)
# IN_DIR <- "/mnt/home/yuankeji/RanceLab/reticula_new/reticula/data/GEO_model_training/input/"
# IN_DIR2 <- "/mnt/home/yuankeji/RanceLab/reticula_new/reticula/data/GEO_model_training/input_shuffled_target/"
#
# graph_targets.df <- read.table(paste(IN_DIR,"graph_targets.txt",sep=""),sep = " ")
#
# graph_targets.df$V1 <- sample(graph_targets.df$V1)
# print(graph_targets.df)
# Out:
#                 V1
# 1            Brain
# 2        Intestine
# 3            Liver
# 4            Sperm
# 5            Brain
# 6      Spinal cord
# 7            Brain
# 8        Intestine
# 9            Heart
# 10           Nerve
# 11           Heart
# 12           Liver
# 13           Liver
# 14           Liver
# 15           Sperm
# 16            Lung
# 17             Eye
# 18           Liver
# 19           Brain
# 20           Liver
# 21       Intestine
# 22           Brain
# 23           Liver
# 24       Olfactory
# 25        Pancreas
# 26             MOE
# 27        Pancreas
# 28            Lung
# 29           Brain
# 30       Olfactory
# 31           Ovary
# 32           Brain
# 33           Ovary
# 34          Kidney
# 35            Lung
# 36       Intestine
# 37           Liver
# 38           Liver
# 39          Muscle
# 40           Liver
# 41             MOE
# 42           Liver
# 43          Kidney
# 44            Lung
# 45           Liver
# 46          Muscle
# ...

# %%
# %%R
# write.table(graph_targets.df,
#             file=paste(IN_DIR2,"shuffled_graph_targets.txt",sep=""),
#             row.names = FALSE,
#             col.names = FALSE)
