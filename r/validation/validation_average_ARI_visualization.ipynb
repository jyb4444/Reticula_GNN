# %%
import pandas as pd
import os
path = "/Users/kejiyuan/Desktop/materials/Validation_ARI/"
file_names = ["top_10_Lung_rxns.csv",
    "top_10_MOE_rxns.csv",
    "top_10_Muscle_rxns.csv",
    "top_10_Pancreas_rxns.csv",
    "top_10_Skin_rxns.csv",
    "top_10_Testes_rxns.csv",
    "top_10_Liver_rxns.csv",
    "top_10_Kidney_rxns.csv",
    "top_10_Intestine_rxns.csv",
    "top_10_Heart_rxns.csv",
    "top_10_Eye_rxns.csv",
    "top_10_Kidney_rxns.csv",
    "top_10_Adipose_rxns.csv",              
    ]
file_paths = [path + name for name in file_names]

data = {}
for file in file_paths:
    tissue = file.split('_')[3]
    if os.path.exists(file):
        data[tissue] = pd.read_csv(file)
    else:
        print(f"File not found: {file}")

print(data)
# Out:
# {'Lung':       Unnamed: 0         RXN_ID  Lung       ARI
# 0  R-MMU-6798751  R-MMU-6798751     0  0.929524
# 1   R-MMU-416320   R-MMU-416320     0  0.828103
# 2   R-MMU-379048   R-MMU-379048     0  0.934492
# 3   R-MMU-749448   R-MMU-749448     0  0.934492
# 4   R-MMU-749452   R-MMU-749452     0  0.934492
# 5  R-MMU-9010668  R-MMU-9010668     0  0.384140
# 6   R-MMU-166041   R-MMU-166041     0  0.626171
# 7   R-MMU-391155   R-MMU-391155     0  0.391403
# 8  R-MMU-5432814  R-MMU-5432814     0  0.391403
# 9  R-MMU-5432852  R-MMU-5432852     0  0.391403, 'MOE':       Unnamed: 0         RXN_ID  MOE       ARI
# 0    R-MMU-72103    R-MMU-72103    0  0.769508
# 1  R-MMU-9770141  R-MMU-9770141    0  0.749417
# 2  R-MMU-9770142  R-MMU-9770142    0  0.755185
# 3  R-MMU-9770145  R-MMU-9770145    0  0.765490
# 4  R-MMU-9770236  R-MMU-9770236    0  0.753128
# 5  R-MMU-6798748  R-MMU-6798748    0  0.877299
# 6  R-MMU-6800434  R-MMU-6800434    0  0.877975
# 7  R-MMU-6798751  R-MMU-6798751    0  0.929524
# 8   R-MMU-380073   R-MMU-380073    0  0.914570
# 9   R-MMU-749454   R-MMU-749454    0  0.924627, 'Muscle':       Unnamed: 0         RXN_ID    Muscle       ARI
# 0  R-MMU-1632857  R-MMU-1632857  0.004162  0.738163
# 1  R-MMU-5672965  R-MMU-5672965  0.005551  0.930607
# 2  R-MMU-1981120  R-MMU-1981120  0.005566  0.911579
# 3  R-MMU-8948228  R-MMU-8948228  0.005566  0.911579
# 4  R-MMU-8948231  R-MMU-8948231  0.005566  0.911579
# 5  R-MMU-8867756  R-MMU-8867756  0.005590  0.926225
# 6  R-MMU-8868071  R-MMU-8868071  0.005590  0.924227
# 7  R-MMU-8868072  R-MMU-8868072  0.005590  0.924227
# 8  R-MMU-9013110  R-MMU-9013110  0.006226  0.864700
# 9  R-MMU-5252041  R-MMU-5252041  0.006241  0.811726, 'Pancreas':       Unnamed: 0         RXN_ID  Pancreas       ARI
# 0   R-MMU-380073   R-MMU-380073  0.000000  0.914570
# 1   R-MMU-749454   R-MMU-749454  0.000000  0.924627
# 2   R-MMU-749456   R-MMU-749456  0.000000  0.924627
# 3   R-MMU-379044   R-MMU-379044  0.001389  0.951497
# 4  R-MMU-1296127  R-MMU-1296127  0.002079  0.902984
# 5  R-MMU-8980691  R-MMU-8980691  0.002084  0.907583
# 6   R-MMU-379048   R-MMU-379048  0.002759  0.934492
# 7   R-MMU-749448   R-MMU-749448  0.002759  0.934492
# 8   R-MMU-749452   R-MMU-749452  0.002759  0.934492
# 9   R-MMU-416320   R-MMU-416320  0.002778  0.828103, 'Skin':       Unnamed: 0         RXN_ID      Skin       ARI
# 0  R-MMU-6809393  R-MMU-6809393  0.000685  0.868278
# 1  R-MMU-6810357  R-MMU-6810357  0.000685  0.868278
# 2  R-MMU-6810937  R-MMU-6810937  0.000685  0.895792
# 3  R-MMU-6814387  R-MMU-6814387  0.000685  0.891780
# 4  R-MMU-6814734  R-MMU-6814734  0.000685  0.891780
# 5  R-MMU-6814764  R-MMU-6814764  0.000685  0.891780
# 6  R-MMU-6805546  R-MMU-6805546  0.000685  0.760838
# 7  R-MMU-6805573  R-MMU-6805573  0.000685  0.760838
# 8  R-MMU-6806610  R-MMU-6806610  0.000685  0.760838
# 9  R-MMU-6806613  R-MMU-6806613  0.000685  0.760838, 'Testes':       Unnamed: 0         RXN_ID    Testes       ARI
# 0  R-MMU-5652005  R-MMU-5652005  0.002074  0.778024
# 1  R-MMU-5652009  R-MMU-5652009  0.002074  0.778024
# 2  R-MMU-5606226  R-MMU-5606226  0.002778  0.401648
# 3  R-MMU-5629217  R-MMU-5629217  0.002778  0.401648
# 4  R-MMU-1296127  R-MMU-1296127  0.003439  0.902984
# 5  R-MMU-5606252  R-MMU-5606252  0.003453  0.460753
# 6  R-MMU-8956200  R-MMU-8956200  0.003458  0.834132
# 7  R-MMU-5668481  R-MMU-5668481  0.003458  0.834161
# 8   R-MMU-983259   R-MMU-983259  0.003458  0.898040
# 9   R-MMU-983266   R-MMU-983266  0.003458  0.898040, 'Liver':       Unnamed: 0         RXN_ID     Liver       ARI
# 0   R-MMU-203973   R-MMU-203973  0.004153  0.946134
# 1   R-MMU-204008   R-MMU-204008  0.004153  0.946134
# 2   R-MMU-481009   R-MMU-481009  0.004814  0.922225
# 3  R-MMU-5694446  R-MMU-5694446  0.004828  0.944489
# 4  R-MMU-5694417  R-MMU-5694417  0.005508  0.946684
# 5  R-MMU-5694522  R-MMU-5694522  0.005508  0.946684
# 6  R-MMU-5694527  R-MMU-5694527  0.005508  0.946684
# 7  R-MMU-5694418  R-MMU-5694418  0.006217  0.939746
# 8  R-MMU-9033235  R-MMU-9033235  0.007583  0.918404
# 9  R-MMU-9033236  R-MMU-9033236  0.007583  0.918404, 'Kidney':       Unnamed: 0         RXN_ID    Kidney       ARI
# 0  R-MMU-1296045  R-MMU-1296045  0.001394  0.476239
# 1   R-MMU-481009   R-MMU-481009  0.002060  0.922225
# 2  R-MMU-6785648  R-MMU-6785648  0.002074  0.922639
# 3  R-MMU-9761177  R-MMU-9761177  0.002084  0.321569
# 4  R-MMU-1963586  R-MMU-1963586  0.002750  0.918833
# 5  R-MMU-2316434  R-MMU-2316434  0.002754  0.913899
# 6   R-MMU-379048   R-MMU-379048  0.002764  0.934492
# 7   R-MMU-749448   R-MMU-749448  0.002764  0.934492
# 8   R-MMU-749452   R-MMU-749452  0.002764  0.934492
# 9  R-MMU-1250195  R-MMU-1250195  0.002768  0.917849, 'Intestine':       Unnamed: 0         RXN_ID  Intestine       ARI
# 0  R-MMU-5618080  R-MMU-5618080   0.000000  0.838915
# 1  R-MMU-5672329  R-MMU-5672329   0.000000  0.786806
# 2  R-MMU-8849350  R-MMU-8849350   0.000000  0.822985
# 3  R-MMU-8849353  R-MMU-8849353   0.000000  0.826444
# 4  R-MMU-8865774  R-MMU-8865774   0.000000  0.711430
# 5  R-MMU-8867370  R-MMU-8867370   0.000000  0.744571
# 6  R-MMU-9610428  R-MMU-9610428   0.000000  0.785457
# 7  R-MMU-9610641  R-MMU-9610641   0.000000  0.785457
# 8   R-MMU-445071   R-MMU-445071   0.000685  0.776470
# 9  R-MMU-9668419  R-MMU-9668419   0.000685  0.814530, 'Heart':       Unnamed: 0         RXN_ID     Heart       ARI
# 0  R-MMU-6800434  R-MMU-6800434  0.002060  0.877975
# 1   R-MMU-376419   R-MMU-376419  0.002060  0.898330
# 2  R-MMU-2855020  R-MMU-2855020  0.002060  0.850677
# 3  R-MMU-5672965  R-MMU-5672965  0.002745  0.930607
# 4   R-MMU-983147   R-MMU-983147  0.002745  0.877876
# 5   R-MMU-445699   R-MMU-445699  0.002745  0.856253
# 6   R-MMU-445700   R-MMU-445700  0.002745  0.856253
# 7   R-MMU-445704   R-MMU-445704  0.002745  0.856253
# 8   R-MMU-445705   R-MMU-445705  0.002745  0.856253
# 9   R-MMU-382096   R-MMU-382096  0.002754  0.906584, 'Eye':       Unnamed: 0         RXN_ID       Eye       ARI
# 0   R-MMU-380073   R-MMU-380073  0.000699  0.914570
# 1   R-MMU-749454   R-MMU-749454  0.000699  0.924627
# 2   R-MMU-749456   R-MMU-749456  0.000699  0.924627
# 3   R-MMU-379048   R-MMU-379048  0.000699  0.934492
# 4   R-MMU-749448   R-MMU-749448  0.000699  0.934492
# 5   R-MMU-749452   R-MMU-749452  0.000699  0.934492
# 6   R-MMU-392295   R-MMU-392295  0.000699  0.841036
# 7   R-MMU-392300   R-MMU-392300  0.000699  0.841036
# 8  R-MMU-6810937  R-MMU-6810937  0.001375  0.895792
# 9   R-MMU-379044   R-MMU-379044  0.001375  0.951497, 'Adipose':       Unnamed: 0         RXN_ID   Adipose       ARI
# 0  R-MMU-9013024  R-MMU-9013024  0.004838  0.882691
# 1  R-MMU-9013110  R-MMU-9013110  0.006203  0.864700
# 2   R-MMU-379044   R-MMU-379044  0.006208  0.951497
# 3  R-MMU-6814387  R-MMU-6814387  0.006222  0.891780
# 4  R-MMU-6814734  R-MMU-6814734  0.006222  0.891780
# 5  R-MMU-6814764  R-MMU-6814764  0.006222  0.891780
# 6  R-MMU-6785648  R-MMU-6785648  0.006931  0.922639
# 7   R-MMU-109699   R-MMU-109699  0.007606  0.855273
# 8   R-MMU-481007   R-MMU-481007  0.007611  0.926196
# 9  R-MMU-2316434  R-MMU-2316434  0.007611  0.913899}

# %%
ari_levels = {tissue: df['ARI'].mean() for tissue, df in data.items()}
print(ari_levels)
# Out:
# {'Lung': 0.67456237378639, 'MOE': 0.8316723605153221, 'Muscle': 0.8854610669164721, 'Pancreas': 0.9157465022080397, 'Skin': 0.8351039439991477, 'Testes': 0.7187456159347814, 'Liver': 0.9375589652766021, 'Kidney': 0.8196728304659672, 'Intestine': 0.7893065080910121, 'Heart': 0.8767060665100195, 'Eye': 0.909665851331418, 'Adipose': 0.8992234609910985}

# %%
import matplotlib.pyplot as plt

# Tissues and their corresponding ARI levels
tissues = list(ari_levels.keys())
ari_values = list(ari_levels.values())

# Creating the bar chart
plt.figure(figsize=(20, 6))
plt.bar(tissues, ari_values, color='skyblue')
plt.xlabel('Tissue')
plt.ylabel('Top_10 Average ARI Level')
plt.title('Top_10 Average ARI Levels Across Tissues')
plt.xticks(rotation=45)

plt.savefig("/Users/kejiyuan/Desktop/materials/Validation_ARI/validation_average_ari_levels.png")

plt.show()
