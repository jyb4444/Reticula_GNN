# %%
import torch
import numpy
import sklearn
import random
import time
import torch.nn.functional as F
from IPython.display import Javascript
from torch.nn import Linear
from sklearn import preprocessing
from torch_geometric.datasets import TUDataset
from torch_geometric.data import Data, DataLoader
from torch_geometric.nn import GraphConv, global_mean_pool
import matplotlib.pyplot as plt

random.seed = 88888888

# %%
device = cuda0 = torch.device('cuda:0')
cpu = torch.device('cpu')

edges_fn = '/mnt/home/yuankeji/RanceLab/reticula_new/reticula/data/GEO_model_training/input_rewired_network/random_rewired_edges.txt'
node_features_fn = '/mnt/home/yuankeji/RanceLab/reticula_new/reticula/data/GEO_model_training/input/node_features.txt'
graph_targets_fn = '/mnt/home/yuankeji/RanceLab/reticula_new/reticula/data/GEO_model_training/input/graph_targets.txt'

# magic numbers
INPUT_CHANNELS = 1
OUTPUT_CHANNELS = 26
HIDDEN_CHANNELS = 64
BATCH_SIZE = 64
EPOCHS = 500 #set this to 200 - 2000
BENCHMARKING = False

# %%
def read_reactome_graph(edges_fn, node_features_fn):
    edge_v1 = []
    edge_v2 = []

    for line in open(edges_fn, 'r'):
        data = line.split()
        node1 = int(data[0]) - 1 #subtracting to convert R idx to python idx
        node2 = int(data[1]) - 1 # " "
        edge_v1.append( node1 )
        edge_v2.append( node2 )

    return edge_v1, edge_v2

# %%
(edge_v1, edge_v2) = read_reactome_graph(edges_fn, node_features_fn)
print(edge_v1)
print(edge_v2)
# Out:
# [5502, 5061, 1504, 1869, 3218, 234, 4952, 6660, 2, 1020, 6425, 7645, 7137, 2486, 6527, 1845, 1837, 57, 1662, 6228, 674, 6961, 2874, 7823, 878, 6222, 2217, 1950, 352, 6159, 3994, 3492, 6372, 5727, 3998, 3163, 7240, 3499, 3712, 6282, 6269, 6013, 4048, 3174, 2436, 7105, 6585, 7484, 332, 2177, 6880, 1563, 2160, 143, 4850, 6179, 6849, 3466, 1883, 2348, 1360, 577, 7264, 3073, 6255, 3719, 3723, 3648, 3173, 943, 7015, 7146, 1018, 7277, 7591, 4809, 7424, 5897, 2815, 2059, 3741, 2881, 368, 1822, 3146, 2131, 5922, 1990, 5474, 1981, 6406, 3498, 1265, 3067, 84, 7367, 4176, 2900, 2316, 5188, 5445, 2288, 1490, 6013, 392, 7838, 6518, 2273, 5849, 3315, 2826, 2422, 3124, 5, 7409, 7588, 3639, 5988, 1698, 3539, 40, 3239, 5794, 4467, 752, 3899, 7184, 3046, 4236, 4997, 4073, 7161, 920, 1428, 1470, 3192, 682, 4063, 3926, 604, 2177, 470, 2508, 4918, 4951, 5356, 127, 5645, 1787, 1368, 4286, 1955, 1099, 757, 4561, 3697, 6978, 1472, 6467, 1769, 3517, 3910, 5789, 4979, 3177, 394, 4001, 4371, 1428, 5259, 1327, 3753, 3048, 4614, 7613, 3205, 866, 1907, 3159, 912, 1890, 3974, 3858, 3232, 6504, 4639, 749, 5584, 7611, 1779, 1609, 1989, 4758, 362, 3074, 5352, 3019, 7521, 6300, 4108, 6624, 337, 3220, 4195, 1687, 6334, 4384, 4388, 2414, 6624, 1953, 6412, 1498, 1774, 4337, 5960, 2422, 3114, 5106, 6085, 4625, 4710, 2800, 1499, 5060, 2563, 5604, 756, 5837, 1648, 3846, 1013, 1073, 6658, 6893, 2830, 3111, 4589, 7489, 1729, 5402, 2528, 6751, 3802, 5595, 1359, 5636, 6244, 2973, 1635, 5453, 783, 5095, 4918, 1845, 1523, 6680, 1385, 5199, 1650, 6491, 7155, 7767, 4456, 6718, 7048, 3830, 1736, 1077, 4875, 3116, 2665, 6581, 4912, 5492, 1125, 1137, 2432, 2407, 6842, 1017, 170, 4848, 6792, 1789, 3466, 6000, 6879, 2006, 7494, 5980, 5321, 7467, 146, 2638, 4187, 6267, 1764, 5683, 3337, 909, 4685, 7137, 1007, 5059, 407, 989, 319, 627, 4247, 7294, 5965, 6615, 1609, 5744, 570, 6290, 1571, 1521, 7360, 6473, 5072, 980, 1442, 394, 2968, 7023, 3020, 6042, 5503, 242, 1059, 6740, 5932, 7630, 5358, 1400, 3695, 1222, 4857, 1143, 4207, 5349, 3854, 821, 3103, 5353, 1986, 7067, 7041, 5304, 1506, 6491, 4564, 1470, 5810, 992, 5226, 4487, 881, 2660, 1679, 388, 2215, 4894, 1376, 3914, 6999, 1576, 2563, 2923, 353, 3892, 4705, 3267, 1736, 7307, 5829, 1472, 6353, 7742, 6576, 6330, 6749, 5260, 1880, 3705, 1143, 347, 877, 7562, 6735, 1106, 2132, 451, 6096, 6073, 129, 1384, 2996, 4835, 4013, 975, 6258, 2680, 6106, 4898, 4412, 3354, 3946, 3730, 4675, 379, 2732, 7009, 4559, 894, 2208, 6165, 857, 1139, 4781, 108, 4298, 4178, 1903, 2789, 3250, 707, 7186, 5224, 2431, 4240, 3321, 4564, 7602, 1637, 2225, 4072, 5787, 1084, 7360, 1783, 5171, 2343, 6070, 6587, 355, 7328, 5802, 2660, 692, 3583, 2566, 4467, 6502, 6316, 7506, 5250, 4518, 203, 2283, 2346, 4856, 2006, 3154, 2994, 3387, 2042, 2536, 571, 4672, 7079, 2923, 4399, 4888, 3894, 4403, 1666, 1657, 3852, 6260, 2900, 4678, 4302, 6180, 3462, 4905, 4443, 4876, 4496, 3850, 7191, 453, 7521, 5909, 6047, 1961, 1297, 12, 246, 4575, 2223, 6709, 3462, 7604, 2673, 2816, 681, 4477, 5511, 6095, 3466, 1028, 7325, 2704, 5060, 1911, 2433, 1376, 3090, 7516, 2562, 916, 114, 3180, 1220, 442, 5795, 3739, 1842, 751, 4819, 6479, 1909, 5553, 570, 1354, 6849, 405, 6138, 401, 81, 6044, 2143, 5236, 5971, 7588, 7080, 4337, 1768, 2697, 2091, 811, 7041, 4133, 724, 4504, 1909, 6071, 6071, 1447, 4196, 2882, 726, 2028, 5361, 5712, 828, 3997, 5535, 3561, 5061, 5605, 6570, 6137, 5097, 5212, 110, 2153, 7228, 6305, 582, 4687, 7021, 4862, 5095, 299, 4271, 7353, 1988, 2527, 4119, 6476, 1148, 2236, 6624, 6769, 760, 2402, 1679, 324, 4432, 3838, 5221, 3419, 7181, 6087, 916, 4001, 7360, 1651, 6794, 4293, 2589, 4212, 2500, 6901, 4172, 2491, 5379, 309, 3135, 5374, 2883, 6677, 6531, 5283, 4108, 4212, 2427, 6806, 6692, 960, 3154, 2132, 6879, 411, 4859, 7669, 1499, 4592, 155, 67, 3811, 1083, 3245, 5006, 5179, 921, 3773, 3623, 3051, 410, 3934, 2436, 7221, 7161, 4951, 6180, 2924, 5477, 1051, 3870, 7440, 681, 4369, 7014, 4829, 5339, 35, 309, 1179, 5172, 6668, 3392, 2771, 2485, 123, 6984, 1249, 1001, 3151, 4855, ...
# [4910, 391, 2536, 958, 6567, 2346, 2786, 2091, 1918, 6661, 5103, 3127, 1753, 1062, 5468, 1013, 3984, 2154, 1985, 1217, 3327, 6719, 5023, 6056, 7397, 4448, 2181, 1264, 4837, 767, 3294, 2387, 1994, 2573, 93, 6487, 2726, 1183, 993, 5635, 7747, 4472, 4400, 7779, 3820, 5600, 2025, 2013, 21, 3997, 1753, 3994, 2239, 4188, 1777, 7626, 882, 1749, 6132, 6279, 3765, 6764, 3144, 6421, 1101, 1813, 2052, 4575, 4590, 6366, 2991, 4395, 540, 2097, 6691, 4496, 7792, 3768, 6987, 6361, 3059, 501, 4057, 1053, 3992, 4724, 1519, 5524, 4882, 3665, 7064, 3577, 1813, 4493, 5410, 6735, 5790, 681, 6635, 890, 6661, 5743, 5245, 6789, 5611, 412, 5723, 2350, 827, 5707, 1630, 2978, 2203, 3508, 6035, 4486, 3285, 5595, 14, 5581, 632, 7825, 792, 5492, 3140, 6078, 7219, 686, 6734, 4409, 7799, 4176, 2724, 484, 4021, 5939, 5717, 341, 4390, 809, 3382, 5553, 3042, 3941, 6517, 2025, 3230, 4251, 3336, 3457, 2659, 3, 1732, 2040, 7182, 2129, 5498, 2436, 4712, 2211, 572, 3937, 3186, 3682, 1579, 5565, 4897, 1903, 5375, 3652, 4863, 5313, 2899, 6173, 7450, 6263, 2324, 1598, 844, 574, 3344, 7364, 7360, 336, 6417, 5334, 5184, 2388, 725, 5908, 4497, 2953, 1381, 5749, 2141, 3076, 1882, 6138, 1317, 3237, 1888, 63, 3096, 2450, 5659, 279, 1496, 809, 837, 2230, 4657, 5895, 2686, 822, 5939, 3913, 7663, 5259, 4925, 1609, 1772, 4208, 3768, 795, 2032, 3095, 3717, 1421, 270, 5479, 462, 694, 1199, 6513, 3300, 1098, 768, 5458, 1182, 65, 476, 2953, 1640, 4228, 3198, 5049, 6388, 2407, 886, 6693, 6932, 4444, 5567, 1156, 5933, 6520, 3448, 126, 4269, 182, 2588, 1481, 4728, 656, 7308, 843, 1872, 7578, 2346, 4132, 181, 1283, 1125, 795, 6987, 3571, 3042, 1125, 5414, 1084, 7358, 2990, 6356, 601, 4750, 400, 2455, 4734, 2279, 2817, 4202, 5108, 6715, 1240, 528, 5772, 5238, 3352, 7626, 7626, 6845, 6725, 1989, 3735, 7073, 5355, 1077, 606, 3264, 4737, 3409, 832, 1992, 1592, 2383, 1054, 1811, 7568, 1238, 2097, 6468, 1049, 2894, 4269, 552, 3011, 4111, 3945, 4196, 6896, 5173, 7219, 5740, 2563, 7737, 4518, 6572, 126, 5939, 2279, 7434, 2434, 4692, 4100, 2653, 2259, 6927, 5237, 5655, 2660, 7121, 4220, 4101, 7825, 3020, 1719, 2040, 5348, 6585, 6112, 1865, 5973, 5962, 1340, 1164, 84, 3127, 1994, 95, 1132, 4794, 1092, 477, 3697, 2384, 708, 7317, 7100, 7829, 2435, 1339, 2132, 7601, 6909, 14, 3063, 4095, 5543, 7460, 2389, 2240, 147, 4181, 1255, 2084, 7318, 1352, 3811, 1628, 5236, 1628, 7054, 1238, 4849, 4474, 510, 390, 2022, 2894, 2573, 5105, 5436, 6391, 5108, 6880, 7356, 2227, 1557, 1679, 4408, 7021, 3136, 831, 3204, 2050, 956, 4818, 3634, 361, 2591, 6685, 6275, 6717, 3520, 4739, 6922, 4300, 5209, 2244, 1851, 7563, 7241, 3321, 7243, 938, 6965, 5500, 1704, 4134, 4255, 17, 1985, 7631, 2794, 4817, 2479, 127, 1325, 449, 2761, 2898, 2476, 4808, 6229, 6036, 1015, 5339, 373, 4899, 4189, 958, 6980, 1587, 2227, 4545, 5590, 4095, 1788, 3936, 5435, 1910, 486, 7553, 2745, 5115, 2366, 7582, 6454, 6496, 3962, 3270, 6390, 663, 3002, 6300, 7379, 5107, 2333, 6769, 6376, 7704, 3178, 7827, 2078, 3923, 764, 4432, 5573, 4446, 4099, 715, 3445, 4594, 1840, 3804, 7495, 58, 1202, 1469, 1689, 722, 1125, 6175, 403, 7679, 6425, 4442, 2528, 1679, 812, 4169, 2120, 995, 1776, 4302, 3150, 188, 324, 4192, 1424, 2953, 5423, 6893, 553, 751, 6540, 6888, 3041, 2784, 4865, 3717, 3783, 3177, 2972, 241, 4196, 6633, 2751, 5507, 986, 1073, 3617, 168, 2974, 5836, 3391, 1113, 6605, 1074, 6639, 1582, 4740, 6471, 3208, 7629, 343, 1239, 5972, 4216, 6979, 4107, 3078, 5806, 4128, 826, 3809, 1006, 4476, 5409, 6999, 5191, 236, 5212, 63, 6667, 2075, 3239, 4345, 2487, 5329, 3945, 3711, 3214, 775, 7059, 4806, 1285, 4482, 5992, 7568, 302, 7502, 2151, 1063, 6512, 3506, 1778, 5496, 4385, 5717, 7425, 216, 6277, 528, 4751, 3817, 1121, 748, 3827, 4236, 4049, 1062, 1867, 6411, 366, 7203, 1727, 5577, 1429, 7442, 5198, 1908, 433, 7410, 1314, 6000, 4732, 5356, 3668, 5828, 3853, 4622, 5575, 7799, 1081, 4829, 6445, 3619, 4515, 7107, 5343, 4770, 1294, 1038, 1386, 6567, 1335, 6768, 5684, 3713, 4490, 7494, 2398, 3124, 2960, 3858, 5399, 6677, 166, 3954, 2129, 3508, 6420, 2757, 380,  ...

# %%
def build_scratch_loader(batch_size):
  dataset = TUDataset(root='data/TUDataset', name='MUTAG')
  data_list = []
  for graph_obj in dataset:
    x = torch.tensor(graph_obj.x[:,1],dtype=torch.float)
    x = x.unsqueeze(1)
    y = graph_obj.y
    edge_index = graph_obj.edge_index
    data_list.append(Data(x = x, y = y, edge_index = edge_index))

  loader = DataLoader(data_list,batch_size=batch_size,shuffle=True)

  return loader

# %%
def build_reactome_graph_datalist(edge_v1, edge_v2, node_features_fn, graph_targets_fn):
    edge_index = torch.tensor([edge_v1, edge_v2], dtype = torch.long)
    feature_v = numpy.loadtxt(node_features_fn)
    target_v = numpy.loadtxt(graph_targets_fn,dtype=str,delimiter=",")
    
    target_encoder = sklearn.preprocessing.LabelEncoder()
    target_v = target_encoder.fit_transform(target_v)
    
    print(len(feature_v))
    print(len(target_v))

    data_list = []
    for row_idx in range(len(feature_v)):
      features = feature_v[row_idx,:]
      x = torch.tensor(features,dtype=torch.float)
      x = x.unsqueeze(1)
      y = torch.tensor([target_v[row_idx]])
      data_list.append(Data(x = x, y = y, edge_index = edge_index))

    return data_list

def build_reactome_graph_loader(data_list,batch_size):

    loader = DataLoader(data_list,batch_size=batch_size,shuffle=True)

    return loader

# %%
class GNN(torch.nn.Module):
    def __init__(self, hidden_channels):
        super(GNN, self).__init__()

        self.conv1 = GraphConv(INPUT_CHANNELS, hidden_channels)
        self.conv2 = GraphConv(hidden_channels,hidden_channels)
        self.conv3 = GraphConv(hidden_channels,hidden_channels)
        self.lin = Linear(hidden_channels, OUTPUT_CHANNELS)

    def forward(self, x, edge_index, batch, edge_weight=None):
        # 1. Obtain node embeddings 
        x = self.conv1(x, edge_index, edge_weight)
        x = x.relu()
        x = self.conv2(x, edge_index, edge_weight)
        x = x.relu()
        x = self.conv3(x, edge_index, edge_weight)

        # 2. Readout layer
        x = global_mean_pool(x, batch)  # [batch_size, hidden_channels]

        # 3. Apply a final classifier
        x = F.dropout(x, training=self.training)
        x = self.lin(x)
        
        return x

# %%
model = GNN(hidden_channels=HIDDEN_CHANNELS)
model = model.to(device)
optimizer = torch.optim.Adam(model.parameters())
criterion = torch.nn.CrossEntropyLoss()

def train(loader,device):
  model.train()

  for batch in loader:  # Iterate in batches over the training dataset.
    x = batch.x.to(device)
    e = batch.edge_index.to(device)
    b = batch.batch.to(device)
    y = batch.y.to(device)

    out = model(x, e, b)  # Perform a single forward pass.

    loss = criterion(out, y)  # Compute the loss.
    loss.backward()  # Derive gradients.
    optimizer.step()  # Update parameters based on gradients.
    optimizer.zero_grad()  # Clear gradients.

def test(loader,device):
  model.eval()

  correct = 0
  for batch in loader:  # Iterate in batches over the training/test dataset.
    x = batch.x.to(device)
    e = batch.edge_index.to(device)
    b = batch.batch.to(device)
    y = batch.y.to(device)
    out = model(x, e, b)  # Perform a single forward pass.
    loss = criterion(out, y)  # Compute the loss.
    pred = out.argmax(dim=1)  # Use the class with highest probability.
    correct += int((pred == y).sum())  # Check against ground-truth labels.
  return correct / len(loader.dataset)  # Derive ratio of correct predictions.

# %%
acc_str = ''
if(BENCHMARKING):

  test_b_sizes = [1,8,16,32,64,128]

  for test_b_size in test_b_sizes:
    print(f'Executing training routine with batch size = {test_b_size}')
    data_list = build_reactome_graph_datalist(edge_v1, edge_v2, node_features_fn, graph_targets_fn)
    test_batch_size_data_loader = build_reactome_graph_loader(data_list,test_b_size)
  
    start = time.time()
    train(test_batch_size_data_loader,device)
    end = time.time()
    training_time = end - start

    start = time.time()
    train_acc = test(test_batch_size_data_loader,device)
    end = time.time()
    test_time = end - start

    acc_str += f'{train_acc:.4f}\n'
    print(f'Batch Size: {test_b_size}')
    print(f'Training Time: {training_time}')
    print(f'Test Time: {test_time}')
    print(f'Accuracy: {train_acc}')
    BENCHMARKING = False
else:
  data_list = build_reactome_graph_datalist(edge_v1, edge_v2, node_features_fn, graph_targets_fn)
  random.shuffle(data_list)

  BENCHMARKING = True
# Out:
# 6288
# 6288

# %%
if(BENCHMARKING):
  fold_size = 911
  fold = 'full_dataset'
#   >>> train =              z[:fold_size * (fold - 1)] +         z[fold_size * fold:]
#   train_data_list = data_list[:fold_size * (fold - 1)] + data_list[fold_size * fold:]
  #>>> test =              z[fold_size * (fold - 1):fold_size * fold]
  #test_data_list = data_list[fold_size * (fold - 1):fold_size * fold]
  train_data_list = data_list

  print(f'Number of training graphs: {len(train_data_list)}')
  #print(f'Number of test graphs: {len(test_data_list)}')
  train_data_loader = build_reactome_graph_loader(train_data_list,BATCH_SIZE)
  #test_data_loader = build_reactome_graph_loader(test_data_list,BATCH_SIZE)
  for epoch in range(EPOCHS):
    train(train_data_loader,device)
    train_acc = test(train_data_loader,device)
    #test_acc = test(test_data_loader,device) 
    acc_str += f'{train_acc:.4f}'#',{test_acc:.4f}\n'
    print(f'Epoch: {epoch:03d}, Train Acc: {train_acc:.4f}')#', Test Acc: {test_acc:.4f}')

  training_acc_fn = F"graph_classification_acc_rewired10_{fold}.txt"
  path = F"/mnt/home/yuankeji/RanceLab/reticula_new/reticula/data/GEO_model_training/GNN/rewired_network/{training_acc_fn}"
  with open(path, 'w') as writefile:
      writefile.write(acc_str)
  model_save_name = F"trained_pytorch_model_rewired10_fold_{fold}.pt"
  path = F"/mnt/home/yuankeji/RanceLab/reticula_new/reticula/data/GEO_model_training/GNN/rewired_network{model_save_name}" 
  torch.save(model.state_dict(), path)
  print(F"model saved as {path}")
# Out:
# Number of training graphs: 6288
# /mnt/home/yuankeji/anaconda3/lib/python3.11/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Epoch: 000, Train Acc: 0.4823
# Epoch: 001, Train Acc: 0.5259
# Epoch: 002, Train Acc: 0.5337
# Epoch: 003, Train Acc: 0.5253
# Epoch: 004, Train Acc: 0.5383
# Epoch: 005, Train Acc: 0.5623
# Epoch: 006, Train Acc: 0.5701
# Epoch: 007, Train Acc: 0.5829
# Epoch: 008, Train Acc: 0.5784
# Epoch: 009, Train Acc: 0.5903
# Epoch: 010, Train Acc: 0.5984
# Epoch: 011, Train Acc: 0.5824
# Epoch: 012, Train Acc: 0.6037
# Epoch: 013, Train Acc: 0.5989
# Epoch: 014, Train Acc: 0.6056
# Epoch: 015, Train Acc: 0.6053
# Epoch: 016, Train Acc: 0.6059
# Epoch: 017, Train Acc: 0.6069
# Epoch: 018, Train Acc: 0.6070
# Epoch: 019, Train Acc: 0.5918
# Epoch: 020, Train Acc: 0.6088
# Epoch: 021, Train Acc: 0.6048
# Epoch: 022, Train Acc: 0.6089
# Epoch: 023, Train Acc: 0.6128
# Epoch: 024, Train Acc: 0.6169
# Epoch: 025, Train Acc: 0.6175
# Epoch: 026, Train Acc: 0.6204
# Epoch: 027, Train Acc: 0.6193
# Epoch: 028, Train Acc: 0.6143
# Epoch: 029, Train Acc: 0.6066
# Epoch: 030, Train Acc: 0.6247
# Epoch: 031, Train Acc: 0.6244
# Epoch: 032, Train Acc: 0.6233
# Epoch: 033, Train Acc: 0.6261
# Epoch: 034, Train Acc: 0.6280
# Epoch: 035, Train Acc: 0.6277
# Epoch: 036, Train Acc: 0.6417
# Epoch: 037, Train Acc: 0.6312
# Epoch: 038, Train Acc: 0.6307
# Epoch: 039, Train Acc: 0.6264
# Epoch: 040, Train Acc: 0.6358
# Epoch: 041, Train Acc: 0.6377
# Epoch: 042, Train Acc: 0.6382
# Epoch: 043, Train Acc: 0.6212
# Epoch: 044, Train Acc: 0.6331
# Epoch: 045, Train Acc: 0.6352
# Epoch: 046, Train Acc: 0.6423
# Epoch: 047, Train Acc: 0.6366
# Epoch: 048, Train Acc: 0.6466
# Epoch: 049, Train Acc: 0.6471
# Epoch: 050, Train Acc: 0.6434
# Epoch: 051, Train Acc: 0.6504
# Epoch: 052, Train Acc: 0.6479
# Epoch: 053, Train Acc: 0.6396
# Epoch: 054, Train Acc: 0.6433
# Epoch: 055, Train Acc: 0.6504
# Epoch: 056, Train Acc: 0.6527
# Epoch: 057, Train Acc: 0.6482
# Epoch: 058, Train Acc: 0.6454
# Epoch: 059, Train Acc: 0.6547
# Epoch: 060, Train Acc: 0.6535
# Epoch: 061, Train Acc: 0.6306
# Epoch: 062, Train Acc: 0.6611
# Epoch: 063, Train Acc: 0.6624
# Epoch: 064, Train Acc: 0.6628
# Epoch: 065, Train Acc: 0.6586
# Epoch: 066, Train Acc: 0.6644
# Epoch: 067, Train Acc: 0.6778
# Epoch: 068, Train Acc: 0.6702
# Epoch: 069, Train Acc: 0.6773
# Epoch: 070, Train Acc: 0.6606
# Epoch: 071, Train Acc: 0.6800
# Epoch: 072, Train Acc: 0.6679
# Epoch: 073, Train Acc: 0.6788
# Epoch: 074, Train Acc: 0.6781
# Epoch: 075, Train Acc: 0.6753
# Epoch: 076, Train Acc: 0.6880
# Epoch: 077, Train Acc: 0.6792
# Epoch: 078, Train Acc: 0.6795
# Epoch: 079, Train Acc: 0.6797
# Epoch: 080, Train Acc: 0.6473
# Epoch: 081, Train Acc: 0.6875
# Epoch: 082, Train Acc: 0.6902
# Epoch: 083, Train Acc: 0.6800
# Epoch: 084, Train Acc: 0.6912
# Epoch: 085, Train Acc: 0.6958
# Epoch: 086, Train Acc: 0.6942
# Epoch: 087, Train Acc: 0.6977
# Epoch: 088, Train Acc: 0.6608
# Epoch: 089, Train Acc: 0.7053
# Epoch: 090, Train Acc: 0.6956
# Epoch: 091, Train Acc: 0.6824
# Epoch: 092, Train Acc: 0.6937
# Epoch: 093, Train Acc: 0.7015
# Epoch: 094, Train Acc: 0.6961
# Epoch: 095, Train Acc: 0.6988
# Epoch: 096, Train Acc: 0.7042
# Epoch: 097, Train Acc: 0.7063
# Epoch: 098, Train Acc: 0.7066
# Epoch: 099, Train Acc: 0.7099
# Epoch: 100, Train Acc: 0.7129
# Epoch: 101, Train Acc: 0.7024
# Epoch: 102, Train Acc: 0.6961
# Epoch: 103, Train Acc: 0.7123
# Epoch: 104, Train Acc: 0.7069
# Epoch: 105, Train Acc: 0.6993
# Epoch: 106, Train Acc: 0.7001
# Epoch: 107, Train Acc: 0.7107
# Epoch: 108, Train Acc: 0.7219
# Epoch: 109, Train Acc: 0.6920
# Epoch: 110, Train Acc: 0.7201
# Epoch: 111, Train Acc: 0.7222
# Epoch: 112, Train Acc: 0.7185
# Epoch: 113, Train Acc: 0.7215
# Epoch: 114, Train Acc: 0.7184
# Epoch: 115, Train Acc: 0.7258
# Epoch: 116, Train Acc: 0.7228
# Epoch: 117, Train Acc: 0.7223
# Epoch: 118, Train Acc: 0.7199
# Epoch: 119, Train Acc: 0.7198
# Epoch: 120, Train Acc: 0.7282
# Epoch: 121, Train Acc: 0.7217
# Epoch: 122, Train Acc: 0.7230
# Epoch: 123, Train Acc: 0.7261
# Epoch: 124, Train Acc: 0.7303
# Epoch: 125, Train Acc: 0.7298
# Epoch: 126, Train Acc: 0.7288
# Epoch: 127, Train Acc: 0.7312
# Epoch: 128, Train Acc: 0.7222
# Epoch: 129, Train Acc: 0.7414
# Epoch: 130, Train Acc: 0.7145
# Epoch: 131, Train Acc: 0.7341
# Epoch: 132, Train Acc: 0.6904
# Epoch: 133, Train Acc: 0.7265
# Epoch: 134, Train Acc: 0.7390
# Epoch: 135, Train Acc: 0.7249
# Epoch: 136, Train Acc: 0.7322
# Epoch: 137, Train Acc: 0.7349
# Epoch: 138, Train Acc: 0.7441
# Epoch: 139, Train Acc: 0.7295
# Epoch: 140, Train Acc: 0.7448
# Epoch: 141, Train Acc: 0.7457
# Epoch: 142, Train Acc: 0.7363
# Epoch: 143, Train Acc: 0.7428
# Epoch: 144, Train Acc: 0.7425
# Epoch: 145, Train Acc: 0.7428
# Epoch: 146, Train Acc: 0.7549
# Epoch: 147, Train Acc: 0.7376
# Epoch: 148, Train Acc: 0.7615
# Epoch: 149, Train Acc: 0.7384
# Epoch: 150, Train Acc: 0.7416
# Epoch: 151, Train Acc: 0.7559
# Epoch: 152, Train Acc: 0.7517
# Epoch: 153, Train Acc: 0.7578
# Epoch: 154, Train Acc: 0.7414
# Epoch: 155, Train Acc: 0.7564
# Epoch: 156, Train Acc: 0.7545
# Epoch: 157, Train Acc: 0.7505
# Epoch: 158, Train Acc: 0.7481
# Epoch: 159, Train Acc: 0.7537
# Epoch: 160, Train Acc: 0.7573
# Epoch: 161, Train Acc: 0.7503
# Epoch: 162, Train Acc: 0.7586
# Epoch: 163, Train Acc: 0.7584
# Epoch: 164, Train Acc: 0.7659
# Epoch: 165, Train Acc: 0.7524
# Epoch: 166, Train Acc: 0.7513
# Epoch: 167, Train Acc: 0.7552
# Epoch: 168, Train Acc: 0.7556
# Epoch: 169, Train Acc: 0.7607
# Epoch: 170, Train Acc: 0.7661
# Epoch: 171, Train Acc: 0.7546
# Epoch: 172, Train Acc: 0.7705
# Epoch: 173, Train Acc: 0.7702
# Epoch: 174, Train Acc: 0.7556
# Epoch: 175, Train Acc: 0.7642
# Epoch: 176, Train Acc: 0.7789
# Epoch: 177, Train Acc: 0.7675
# Epoch: 178, Train Acc: 0.7712
# Epoch: 179, Train Acc: 0.7468
# Epoch: 180, Train Acc: 0.7570
# Epoch: 181, Train Acc: 0.7700
# Epoch: 182, Train Acc: 0.7820
# Epoch: 183, Train Acc: 0.7587
# Epoch: 184, Train Acc: 0.7610
# Epoch: 185, Train Acc: 0.7654
# Epoch: 186, Train Acc: 0.7473
# Epoch: 187, Train Acc: 0.7801
# Epoch: 188, Train Acc: 0.7739
# Epoch: 189, Train Acc: 0.7638
# Epoch: 190, Train Acc: 0.7724
# Epoch: 191, Train Acc: 0.7805
# Epoch: 192, Train Acc: 0.7762
# Epoch: 193, Train Acc: 0.7578
# Epoch: 194, Train Acc: 0.7727
# Epoch: 195, Train Acc: 0.7815
# Epoch: 196, Train Acc: 0.7634
# Epoch: 197, Train Acc: 0.7591
# Epoch: 198, Train Acc: 0.7648
# Epoch: 199, Train Acc: 0.7818
# Epoch: 200, Train Acc: 0.7778
# Epoch: 201, Train Acc: 0.7810
# Epoch: 202, Train Acc: 0.7818
# Epoch: 203, Train Acc: 0.7754
# Epoch: 204, Train Acc: 0.7866
# Epoch: 205, Train Acc: 0.7697
# Epoch: 206, Train Acc: 0.7809
# Epoch: 207, Train Acc: 0.7801
# Epoch: 208, Train Acc: 0.7851
# Epoch: 209, Train Acc: 0.7869
# Epoch: 210, Train Acc: 0.7917
# Epoch: 211, Train Acc: 0.7869
# Epoch: 212, Train Acc: 0.7902
# Epoch: 213, Train Acc: 0.7926
# Epoch: 214, Train Acc: 0.7867
# Epoch: 215, Train Acc: 0.7769
# Epoch: 216, Train Acc: 0.7837
# Epoch: 217, Train Acc: 0.7788
# Epoch: 218, Train Acc: 0.7742
# Epoch: 219, Train Acc: 0.7953
# Epoch: 220, Train Acc: 0.7907
# Epoch: 221, Train Acc: 0.7818
# Epoch: 222, Train Acc: 0.7875
# Epoch: 223, Train Acc: 0.7918
# Epoch: 224, Train Acc: 0.7742
# Epoch: 225, Train Acc: 0.7864
# Epoch: 226, Train Acc: 0.7801
# Epoch: 227, Train Acc: 0.7885
# Epoch: 228, Train Acc: 0.7772
# Epoch: 229, Train Acc: 0.7969
# Epoch: 230, Train Acc: 0.7781
# Epoch: 231, Train Acc: 0.7991
# Epoch: 232, Train Acc: 0.7963
# Epoch: 233, Train Acc: 0.7893
# Epoch: 234, Train Acc: 0.7947
# Epoch: 235, Train Acc: 0.7969
# Epoch: 236, Train Acc: 0.8031
# Epoch: 237, Train Acc: 0.7980
# Epoch: 238, Train Acc: 0.7980
# Epoch: 239, Train Acc: 0.7920
# Epoch: 240, Train Acc: 0.7839
# Epoch: 241, Train Acc: 0.7972
# Epoch: 242, Train Acc: 0.7824
# Epoch: 243, Train Acc: 0.7974
# Epoch: 244, Train Acc: 0.8030
# Epoch: 245, Train Acc: 0.7934
# Epoch: 246, Train Acc: 0.8045
# Epoch: 247, Train Acc: 0.7947
# Epoch: 248, Train Acc: 0.8022
# Epoch: 249, Train Acc: 0.7948
# Epoch: 250, Train Acc: 0.8074
# Epoch: 251, Train Acc: 0.8065
# Epoch: 252, Train Acc: 0.8069
# Epoch: 253, Train Acc: 0.7955
# Epoch: 254, Train Acc: 0.7985
# Epoch: 255, Train Acc: 0.7753
# Epoch: 256, Train Acc: 0.8042
# Epoch: 257, Train Acc: 0.7956
# Epoch: 258, Train Acc: 0.8114
# Epoch: 259, Train Acc: 0.7974
# Epoch: 260, Train Acc: 0.8112
# Epoch: 261, Train Acc: 0.8063
# Epoch: 262, Train Acc: 0.7972
# Epoch: 263, Train Acc: 0.7991
# Epoch: 264, Train Acc: 0.8007
# Epoch: 265, Train Acc: 0.8009
# Epoch: 266, Train Acc: 0.7976
# Epoch: 267, Train Acc: 0.8085
# Epoch: 268, Train Acc: 0.7982
# Epoch: 269, Train Acc: 0.8114
# Epoch: 270, Train Acc: 0.8028
# Epoch: 271, Train Acc: 0.7802
# Epoch: 272, Train Acc: 0.7998
# Epoch: 273, Train Acc: 0.8049
# Epoch: 274, Train Acc: 0.8119
# Epoch: 275, Train Acc: 0.8015
# Epoch: 276, Train Acc: 0.8057
# Epoch: 277, Train Acc: 0.8098
# Epoch: 278, Train Acc: 0.7971
# Epoch: 279, Train Acc: 0.8162
# Epoch: 280, Train Acc: 0.8117
# Epoch: 281, Train Acc: 0.8085
# Epoch: 282, Train Acc: 0.8163
# Epoch: 283, Train Acc: 0.8026
# Epoch: 284, Train Acc: 0.8195
# Epoch: 285, Train Acc: 0.8080
# Epoch: 286, Train Acc: 0.8211
# Epoch: 287, Train Acc: 0.8090
# Epoch: 288, Train Acc: 0.8047
# Epoch: 289, Train Acc: 0.8115
# Epoch: 290, Train Acc: 0.8152
# Epoch: 291, Train Acc: 0.8061
# Epoch: 292, Train Acc: 0.8165
# Epoch: 293, Train Acc: 0.7977
# Epoch: 294, Train Acc: 0.8170
# Epoch: 295, Train Acc: 0.8022
# Epoch: 296, Train Acc: 0.7915
# Epoch: 297, Train Acc: 0.8152
# Epoch: 298, Train Acc: 0.8179
# Epoch: 299, Train Acc: 0.8216
# Epoch: 300, Train Acc: 0.8219
# Epoch: 301, Train Acc: 0.8173
# Epoch: 302, Train Acc: 0.8206
# Epoch: 303, Train Acc: 0.8271
# Epoch: 304, Train Acc: 0.8217
# Epoch: 305, Train Acc: 0.8103
# Epoch: 306, Train Acc: 0.8228
# Epoch: 307, Train Acc: 0.8247
# Epoch: 308, Train Acc: 0.8036
# Epoch: 309, Train Acc: 0.8179
# Epoch: 310, Train Acc: 0.8209
# Epoch: 311, Train Acc: 0.8282
# Epoch: 312, Train Acc: 0.8279
# Epoch: 313, Train Acc: 0.8220
# Epoch: 314, Train Acc: 0.8236
# Epoch: 315, Train Acc: 0.8205
# Epoch: 316, Train Acc: 0.8222
# Epoch: 317, Train Acc: 0.8158
# Epoch: 318, Train Acc: 0.8217
# Epoch: 319, Train Acc: 0.8249
# Epoch: 320, Train Acc: 0.8200
# Epoch: 321, Train Acc: 0.8007
# Epoch: 322, Train Acc: 0.8217
# Epoch: 323, Train Acc: 0.8185
# Epoch: 324, Train Acc: 0.8290
# Epoch: 325, Train Acc: 0.8225
# Epoch: 326, Train Acc: 0.8241
# Epoch: 327, Train Acc: 0.8206
# Epoch: 328, Train Acc: 0.8271
# Epoch: 329, Train Acc: 0.8254
# Epoch: 330, Train Acc: 0.8050
# Epoch: 331, Train Acc: 0.8141
# Epoch: 332, Train Acc: 0.8225
# Epoch: 333, Train Acc: 0.8251
# Epoch: 334, Train Acc: 0.8023
# Epoch: 335, Train Acc: 0.8254
# Epoch: 336, Train Acc: 0.8284
# Epoch: 337, Train Acc: 0.8227
# Epoch: 338, Train Acc: 0.8240
# Epoch: 339, Train Acc: 0.8341
# Epoch: 340, Train Acc: 0.8308
# Epoch: 341, Train Acc: 0.8306
# Epoch: 342, Train Acc: 0.8333
# Epoch: 343, Train Acc: 0.8138
# Epoch: 344, Train Acc: 0.8176
# Epoch: 345, Train Acc: 0.8332
# Epoch: 346, Train Acc: 0.8286
# Epoch: 347, Train Acc: 0.8379
# Epoch: 348, Train Acc: 0.8300
# Epoch: 349, Train Acc: 0.8227
# Epoch: 350, Train Acc: 0.8321
# Epoch: 351, Train Acc: 0.8260
# Epoch: 352, Train Acc: 0.8227
# Epoch: 353, Train Acc: 0.8330
# Epoch: 354, Train Acc: 0.8351
# Epoch: 355, Train Acc: 0.8341
# Epoch: 356, Train Acc: 0.8348
# Epoch: 357, Train Acc: 0.8381
# Epoch: 358, Train Acc: 0.8228
# Epoch: 359, Train Acc: 0.8217
# Epoch: 360, Train Acc: 0.8267
# Epoch: 361, Train Acc: 0.8222
# Epoch: 362, Train Acc: 0.8395
# Epoch: 363, Train Acc: 0.8303
# Epoch: 364, Train Acc: 0.8313
# Epoch: 365, Train Acc: 0.8319
# Epoch: 366, Train Acc: 0.8241
# Epoch: 367, Train Acc: 0.8335
# Epoch: 368, Train Acc: 0.8394
# Epoch: 369, Train Acc: 0.8432
# Epoch: 370, Train Acc: 0.8397
# Epoch: 371, Train Acc: 0.8414
# Epoch: 372, Train Acc: 0.8344
# Epoch: 373, Train Acc: 0.8197
# Epoch: 374, Train Acc: 0.8362
# Epoch: 375, Train Acc: 0.8352
# Epoch: 376, Train Acc: 0.8400
# Epoch: 377, Train Acc: 0.8364
# Epoch: 378, Train Acc: 0.8306
# Epoch: 379, Train Acc: 0.8340
# Epoch: 380, Train Acc: 0.8192
# Epoch: 381, Train Acc: 0.8302
# Epoch: 382, Train Acc: 0.8378
# Epoch: 383, Train Acc: 0.8459
# Epoch: 384, Train Acc: 0.8290
# Epoch: 385, Train Acc: 0.8421
# Epoch: 386, Train Acc: 0.8424
# Epoch: 387, Train Acc: 0.8391
# Epoch: 388, Train Acc: 0.8263
# Epoch: 389, Train Acc: 0.8170
# Epoch: 390, Train Acc: 0.8276
# Epoch: 391, Train Acc: 0.8437
# Epoch: 392, Train Acc: 0.8212
# Epoch: 393, Train Acc: 0.8413
# Epoch: 394, Train Acc: 0.8251
# Epoch: 395, Train Acc: 0.8325
# Epoch: 396, Train Acc: 0.8426
# Epoch: 397, Train Acc: 0.8375
# Epoch: 398, Train Acc: 0.8443
# Epoch: 399, Train Acc: 0.8521
# Epoch: 400, Train Acc: 0.8356
# Epoch: 401, Train Acc: 0.8489
# Epoch: 402, Train Acc: 0.8464
# Epoch: 403, Train Acc: 0.8446
# Epoch: 404, Train Acc: 0.8392
# Epoch: 405, Train Acc: 0.8364
# Epoch: 406, Train Acc: 0.8324
# Epoch: 407, Train Acc: 0.8484
# Epoch: 408, Train Acc: 0.8445
# Epoch: 409, Train Acc: 0.8432
# Epoch: 410, Train Acc: 0.8453
# Epoch: 411, Train Acc: 0.8481
# Epoch: 412, Train Acc: 0.8364
# Epoch: 413, Train Acc: 0.8360
# Epoch: 414, Train Acc: 0.8430
# Epoch: 415, Train Acc: 0.8481
# Epoch: 416, Train Acc: 0.8405
# Epoch: 417, Train Acc: 0.8370
# Epoch: 418, Train Acc: 0.8446
# Epoch: 419, Train Acc: 0.8387
# Epoch: 420, Train Acc: 0.8427
# Epoch: 421, Train Acc: 0.8422
# Epoch: 422, Train Acc: 0.8503
# Epoch: 423, Train Acc: 0.8465
# Epoch: 424, Train Acc: 0.8422
# Epoch: 425, Train Acc: 0.8496
# Epoch: 426, Train Acc: 0.8497
# Epoch: 427, Train Acc: 0.8364
# Epoch: 428, Train Acc: 0.8287
# Epoch: 429, Train Acc: 0.8523
# Epoch: 430, Train Acc: 0.8497
# Epoch: 431, Train Acc: 0.8503
# Epoch: 432, Train Acc: 0.8484
# Epoch: 433, Train Acc: 0.8454
# Epoch: 434, Train Acc: 0.8295
# Epoch: 435, Train Acc: 0.8387
# Epoch: 436, Train Acc: 0.8531
# Epoch: 437, Train Acc: 0.8395
# Epoch: 438, Train Acc: 0.8429
# Epoch: 439, Train Acc: 0.8540
# Epoch: 440, Train Acc: 0.8494
# Epoch: 441, Train Acc: 0.8550
# Epoch: 442, Train Acc: 0.8532
# Epoch: 443, Train Acc: 0.8441
# Epoch: 444, Train Acc: 0.8480
# Epoch: 445, Train Acc: 0.8570
# Epoch: 446, Train Acc: 0.8513
# Epoch: 447, Train Acc: 0.8348
# Epoch: 448, Train Acc: 0.8376
# Epoch: 449, Train Acc: 0.8327
# Epoch: 450, Train Acc: 0.8604
# Epoch: 451, Train Acc: 0.8491
# Epoch: 452, Train Acc: 0.8608
# Epoch: 453, Train Acc: 0.8484
# Epoch: 454, Train Acc: 0.8454
# Epoch: 455, Train Acc: 0.8575
# Epoch: 456, Train Acc: 0.8503
# Epoch: 457, Train Acc: 0.8359
# Epoch: 458, Train Acc: 0.8626
# Epoch: 459, Train Acc: 0.8596
# Epoch: 460, Train Acc: 0.8454
# Epoch: 461, Train Acc: 0.8567
# Epoch: 462, Train Acc: 0.8457
# Epoch: 463, Train Acc: 0.8459
# Epoch: 464, Train Acc: 0.8464
# Epoch: 465, Train Acc: 0.8538
# Epoch: 466, Train Acc: 0.8546
# Epoch: 467, Train Acc: 0.8441
# Epoch: 468, Train Acc: 0.8448
# Epoch: 469, Train Acc: 0.8613
# Epoch: 470, Train Acc: 0.8548
# Epoch: 471, Train Acc: 0.8317
# Epoch: 472, Train Acc: 0.8635
# Epoch: 473, Train Acc: 0.8605
# Epoch: 474, Train Acc: 0.8505
# Epoch: 475, Train Acc: 0.8461
# Epoch: 476, Train Acc: 0.8570
# Epoch: 477, Train Acc: 0.8538
# Epoch: 478, Train Acc: 0.8575
# Epoch: 479, Train Acc: 0.8554
# Epoch: 480, Train Acc: 0.8408
# Epoch: 481, Train Acc: 0.8651
# Epoch: 482, Train Acc: 0.8405
# Epoch: 483, Train Acc: 0.8599
# Epoch: 484, Train Acc: 0.8480
# Epoch: 485, Train Acc: 0.8604
# Epoch: 486, Train Acc: 0.8472
# Epoch: 487, Train Acc: 0.8643
# Epoch: 488, Train Acc: 0.8497
# Epoch: 489, Train Acc: 0.8701
# Epoch: 490, Train Acc: 0.8558
# Epoch: 491, Train Acc: 0.8663
# Epoch: 492, Train Acc: 0.8634
# Epoch: 493, Train Acc: 0.8457
# Epoch: 494, Train Acc: 0.8561
# Epoch: 495, Train Acc: 0.8356
# Epoch: 496, Train Acc: 0.8496
# Epoch: 497, Train Acc: 0.8575
# Epoch: 498, Train Acc: 0.8537
# Epoch: 499, Train Acc: 0.8357
# model saved as /mnt/home/yuankeji/RanceLab/reticula_new/reticula/data/GEO_model_training/GNN/rewired_networktrained_pytorch_model_rewired10_fold_full_dataset.pt
